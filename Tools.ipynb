# %%
# This cell is to ignore ugly warnings 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Automatic Email
#
# **Tool:**
#
# Automatic Email Sender is a tool that sends a report to 3PLs about their fleet performance. The report is sent through email and is divided in 2 parts: 1 in the body of the email and the second in a PDF file. It has different section sections and contains the previous day data or the previous 7 days if the period chosen is "weekly":
# * **AFM actions :** list of couriers affected by AFM and what the 3pl should do about them
# * **Worst Offenders :** list of WO in NS, Reass and CNM and what to do in each case
# * **Fraudulent Couriers :** list of couriers that might have : GPS fraud, CAPUs fraud and other types of fraud
# * **3PL fleet performance VS average performance :** charts of KPIs of 3PL fleet
# * **Active couriers (weekly) :** chart of active couriers VS available couriers
#
# **Guide:**
#
# To use this tool, just execute the cell. If today is monday , the weekly report is sent. Otherwise, the daily report is sent.
# You can force a certain period by adding an argument (either "weekly" or "daily") to the function: send_reports("\[period\]").
# The last step is the only manual step and it is allowing the tool the access to your Gmail account to send the emails.
#
# **Important!**
#
# Before confirming sending the emails, always check if the pdf reports are correct by checking the date and whether some sections are missing. Check all reports to confirm!

# %%
from AutomaticEmailSender import send_reports

send_reports()
# Out:
# C:\Users\HP\Desktop\ops\utilities\dataLoader.py:47: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)
# Open the following URL in browser for the external authentication:
# https://starburst.g8s-data-platform-prod.glovoint.com/oauth2/token/initiate/0e32c115dfb474fc4beca361c84b7bc84d260e5320d958f05e9a432c07c36385
# C:\Users\HP\Desktop\ops\utilities\dataLoader.py:47: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query(query, conn)
# step 1 (done): courier data loaded
# step 2 (done): courier data saved
# C:\Users\HP\Desktop\ops\reportGenerator\dataPreprocessor.py:67: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   acc_funnel_df["accelarted"] = True
# step 3 (done): courier data processed
# C:\Users\HP\Desktop\ops\reportGenerator\dataProcessor.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gps_fraud_couriers.drop(["date", "3pl_id", "adress", "phone"], axis=1, inplace=True)
# C:\Users\HP\Desktop\ops\reportGenerator\dataProcessor.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   check_in_no_work_couriers.drop(["date", "3pl_id", "adress", "phone"], axis=1, inplace=True)
# C:\Users\HP\Desktop\ops\reportGenerator\dataProcessor.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gps_fraud_couriers.drop(["date", "3pl_id", "adress", "phone"], axis=1, inplace=True)
# C:\Users\HP\Desktop\ops\reportGenerator\dataProcessor.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   check_in_no_work_couriers.drop(["date", "3pl_id", "adress", "phone"], axis=1, inplace=True)
# C:\Users\HP\Desktop\ops\reportGenerator\dataProcessor.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gps_fraud_couriers.drop(["date", "3pl_id", "adress", "phone"], axis=1, inplace=True)
# C:\Users\HP\Desktop\ops\reportGenerator\dataProcessor.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   check_in_no_work_couriers.drop(["date", "3pl_id", "adress", "phone"], axis=1, inplace=True)
# C:\Users\HP\Desktop\ops\reportGenerator\dataProcessor.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gps_fraud_couriers.drop(["date", "3pl_id", "adress", "phone"], axis=1, inplace=True)
# C:\Users\HP\Desktop\ops\reportGenerator\dataProcessor.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   check_in_no_work_couriers.drop(["date", "3pl_id", "adress", "phone"], axis=1, inplace=True)
# C:\Users\HP\Desktop\ops\reportGenerator\pdfGenerator.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   check_in_no_work_couriers["excellence_score"] = check_in_no_work_couriers["excellence_score"].apply(lambda x: np.round(x, 2))
# C:\Users\HP\Desktop\ops\reportGenerator\dataProcessor.py:19: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`). Consider using `matplotlib.pyplot.close()`.
#   plt.figure(figsize=(7, 7))
# C:\Users\HP\Desktop\ops\reportGenerator\dataProcessor.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gps_fraud_couriers.drop(["date", "3pl_id", "adress", "phone"], axis=1, inplace=True)
# C:\Users\HP\Desktop\ops\reportGenerator\dataProcessor.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   check_in_no_work_couriers.drop(["date", "3pl_id", "adress", "phone"], axis=1, inplace=True)
# C:\Users\HP\Desktop\ops\reportGenerator\dataProcessor.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gps_fraud_couriers.drop(["date", "3pl_id", "adress", "phone"], axis=1, inplace=True)
# C:\Users\HP\Desktop\ops\reportGenerator\dataProcessor.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   check_in_no_work_couriers.drop(["date", "3pl_id", "adress", "phone"], axis=1, inplace=True)
# C:\Users\HP\Desktop\ops\reportGenerator\dataProcessor.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gps_fraud_couriers.drop(["date", "3pl_id", "adress", "phone"], axis=1, inplace=True)
# C:\Users\HP\Desktop\ops\reportGenerator\dataProcessor.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   check_in_no_work_couriers.drop(["date", "3pl_id", "adress", "phone"], axis=1, inplace=True)
# C:\Users\HP\Desktop\ops\reportGenerator\dataProcessor.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gps_fraud_couriers.drop(["date", "3pl_id", "adress", "phone"], axis=1, inplace=True)
# C:\Users\HP\Desktop\ops\reportGenerator\dataProcessor.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   check_in_no_work_couriers.drop(["date", "3pl_id", "adress", "phone"], axis=1, inplace=True)
# C:\Users\HP\Desktop\ops\reportGenerator\dataProcessor.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gps_fraud_couriers.drop(["date", "3pl_id", "adress", "phone"], axis=1, inplace=True)
# C:\Users\HP\Desktop\ops\reportGenerator\dataProcessor.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   check_in_no_work_couriers.drop(["date", "3pl_id", "adress", "phone"], axis=1, inplace=True)
# C:\Users\HP\Desktop\ops\reportGenerator\dataProcessor.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gps_fraud_couriers.drop(["date", "3pl_id", "adress", "phone"], axis=1, inplace=True)
# C:\Users\HP\Desktop\ops\reportGenerator\dataProcessor.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   check_in_no_work_couriers.drop(["date", "3pl_id", "adress", "phone"], axis=1, inplace=True)
# C:\Users\HP\Desktop\ops\reportGenerator\pdfGenerator.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   check_in_no_work_couriers["excellence_score"] = check_in_no_work_couriers["excellence_score"].apply(lambda x: np.round(x, 2))
# C:\Users\HP\Desktop\ops\reportGenerator\dataProcessor.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gps_fraud_couriers.drop(["date", "3pl_id", "adress", "phone"], axis=1, inplace=True)
# C:\Users\HP\Desktop\ops\reportGenerator\dataProcessor.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   check_in_no_work_couriers.drop(["date", "3pl_id", "adress", "phone"], axis=1, inplace=True)
# C:\Users\HP\Desktop\ops\reportGenerator\pdfGenerator.py:140: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   check_in_no_work_couriers["excellence_score"] = check_in_no_work_couriers["excellence_score"].apply(lambda x: np.round(x, 2))
# C:\Users\HP\Desktop\ops\reportGenerator\dataProcessor.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gps_fraud_couriers.drop(["date", "3pl_id", "adress", "phone"], axis=1, inplace=True)
# C:\Users\HP\Desktop\ops\reportGenerator\dataProcessor.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   check_in_no_work_couriers.drop(["date", "3pl_id", "adress", "phone"], axis=1, inplace=True)
# C:\Users\HP\Desktop\ops\reportGenerator\dataProcessor.py:112: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gps_fraud_couriers.drop(["date", "3pl_id", "adress", "phone"], axis=1, inplace=True)
# C:\Users\HP\Desktop\ops\reportGenerator\dataProcessor.py:127: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   check_in_no_work_couriers.drop(["date", "3pl_id", "adress", "phone"], axis=1, inplace=True)
# step 4 (done): reports generated
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=315024983370-mbe70gcargecd0eh2q68sshv909965rm.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A61534%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fgmail.send&state=WkJ70ifiNvQCEwySWTAHoJbVaxz9Yd&access_type=offline
# step 5 (done): reports sent

# %% [markdown]
# # Admin Manager (WIP)
#
# **Tool:**
#
# Admin manager is a tool that allows you to interact with Admin Panel through code. This allows mass action that otherwise would take a lot of time.
#
# **Guide:**
#
# To use this tool, you need an access token. To get your token, follow the steps in the video below and grab the "accessToken" instead of "refreshToken". Watch the video you will notice it.
# https://drive.google.com/file/d/12_3gsVB96Oobn6MW4xiUBY4DPHBZydjL/view
#
# **Functionalities:**
#    * rebook_kickedout_couriers(token,courier_id:optional,slot_id:optional) :
#        * to rebook all couriers mentioned in Kickouts sheet, *do not add* a courier_id and a slot_id
#        * to rebook a specific courier, add the optional arguments
#
# **Important!**
#
# Do not forget to download data from this sheet **after** running it. After downloading it do not change the name, it needs to be "TN Booked Slots _ Couriers (deprecated) - Kickouts" (until we find a better name). Finally do not forget to change the token using the guide above, old tokens might not work.
#
#
# ![image.png](attachment:image.png)

# %%
from Admin import Admin

token = "eyJraWQiOiJvbGQiLCJhbGciOiJSUzUxMiJ9..MrDdSvHD5IyN3Q5q4wZc4yMmoU1OgYS5Ax06luQjL-MD0AKluZ2B5aFXoSYkrhQajDSzDLNz4MBrC_FQ8zxgDsD_qfP4pERu0QuTWX3_w7zXjdXgaVTRRMyGN2J9eWOzlGRS0lY2nCC9Z42vVMcO0phGKZ4ajE5KWcMhqD4byNVJAajVfgp8a6rrDetOMV5-HGvqLel_gy9hWRiFFhdyfBUkDQ0FEBgOfF1As4o-Y65gXxX5qVC4Q7aSfaBPUwbdyaERWItscXxM1ghugdDfovPx7SQ5oVAoWDOT_kvC13c9Ej3sVcqJsLyuRyFhOAjbUuC55To2Mu63-u_cwp0zrw"
refresh_token = "eyJraWQiOiJvbGQiLCJhbGciOiJSUzUxMiJ9.eyJpYXQiOjE3MDkzMTU2NzEsImlzcyI6ImF1dGgiLCJyb2xlIjoiUkVGUkVTSCIsInBheWxvYWQiOiJ7XCJ1c2VySWRcIjoxNTYyNzI4NDMsXCJncmFudFR5cGVcIjpcIlNTT1wifSIsInZlcnNpb24iOiJWMiIsImp0aSI6ImU4NjJhNTVlLTUwYTctNDkxNS05NjcxLWJhOWVmZGE4NzkwZCJ9.CmHlV3x8q328cWJRfoB35mGk-P0y4ad4G_U-RQCw3rQh0vzFMHakSlxMnmYdDe80qWz8w_WGi2joeKDtwTw9xAPyg2eDLmxGNY1W1tDfPSXxZjouqhbu0lQ1fdr1vBLP9fcTFFhLGeqVDFxRbPcQ38FZmrtUa11XQUjMVemfGpojX3U5iMt-JxN2zrYYDrOoZDHyWwNKjMwVQHuDUVqeMHLE_Smi-1QyYnASYdOymInCgAS_f172xTNmblQbZ8B8sVceXRQYxmh0Kdqy_oDUJh-jxcHjwTKl8shp5zLnWqxEuTTo4rSoFnXC10joPUyk8ybZMvZW2ha0ioBv503_tQ"
admin = Admin(token,refresh_token)

# %%
# rebook kicked out (late check in and reassignement) couriers during saturation
admin.rebook_kickedout_couriers(token)
# Out:
# 134372652 37935795 (True, {})
# 134372652 37935795 (True, {})
# 137145862 37935795 (True, {})
# 137145862 37935795 (True, {})
# 145433623 37935795 (True, {})
# 145433623 37935795 (True, {})
# 150833713 37935794 (True, {})
# 150833713 37935794 (True, {})
# 152755288 37935793 (True, {})
# 152755288 37935793 (True, {})
# 153277287 37935793 (True, {})
# 153277287 37935793 (True, {})
# 153692413 37935795 (True, {})
# 153692413 37935795 (True, {})
# 154952269 37935794 (True, {})
# 154952269 37935794 (True, {})
# 159529533 37935795 (True, {})
# 159529533 37935795 (True, {})
# 160736307 37935220 (True, {})
# 160736307 37935220 (True, {})
# 160806766 37935795 (True, {})
# 160806766 37935795 (True, {})
# 161240872 37935220 (True, {})
# 161240872 37935220 (True, {})
# 161270330 37935795 (True, {})
# 161270330 37935795 (True, {})
# 162378734 37935793 (True, {})
# 162378734 37935793 (True, {})
# 164678163 37935795 (True, {})
# 164678163 37935795 (True, {})
# 165751222 37935220 (True, {})
# 165751222 37935220 (True, {})
# 166048365 37935795 (True, {})
# 166048365 37935795 (True, {})
# 166154359 37935795 (True, {})
# 166154359 37935795 (True, {})
# 166198095 37935795 (True, {})
# 166198095 37935795 (True, {})

# %%
# setup newly onboarded couriers profiles
admin.setup_new_couriers_profiles()
# Out:
# {'tags': [{'id': 220, 'name': 'walker', 'addedByFilter': True}, {'id': 499, 'name': 'staff', 'addedByFilter': True}, {'id': 652, 'name': 'walkers', 'addedByFilter': True}]}
# courier_id:  165012073 slot_id:  37935515 successful booking:  True
# courier_id:  165012073 slot_id:  37935518 successful booking:  True
# courier_id:  165012073 slot_id:  37935563 successful booking:  True
# courier_id:  165012073 slot_id:  37935566 successful booking:  True
# courier_id:  165012073 slot_id:  37935569 successful booking:  True
# courier_id:  165012073 slot_id:  37935572 successful booking:  True
# courier_id:  165012073 slot_id:  37935575 successful booking:  True
# courier_id:  165012073 slot_id:  37935578 successful booking:  True
# courier_id:  165012073 slot_id:  37935581 successful booking:  True
# courier_id:  165012073 slot_id:  37935584 successful booking:  True
# courier_id:  165012073 slot_id:  38056801 successful booking:  True
# courier_id:  165012073 slot_id:  38056804 successful booking:  True
# courier_id:  165012073 slot_id:  38056849 successful booking:  True
# courier_id:  165012073 slot_id:  38056852 successful booking:  True
# courier_id:  165012073 slot_id:  38056855 successful booking:  True
# courier_id:  165012073 slot_id:  38056858 successful booking:  True
# courier_id:  165012073 slot_id:  38056861 successful booking:  True
# courier_id:  165012073 slot_id:  38056864 successful booking:  True
# courier_id:  165012073 slot_id:  38056867 successful booking:  True
# courier_id:  165012073 slot_id:  38056870 successful booking:  True
# courier_id:  165012073 slot_id:  38056657 successful booking:  True
# courier_id:  165012073 slot_id:  38056660 successful booking:  True
# courier_id:  165012073 slot_id:  38056705 successful booking:  True
# courier_id:  165012073 slot_id:  38056708 successful booking:  True
# courier_id:  165012073 slot_id:  38056711 successful booking:  True
# courier_id:  165012073 slot_id:  38056714 successful booking:  True
# courier_id:  165012073 slot_id:  38056717 successful booking:  True
# courier_id:  165012073 slot_id:  38056720 successful booking:  True
# courier_id:  165012073 slot_id:  38056723 successful booking:  True
# courier_id:  165012073 slot_id:  38056726 successful booking:  True
# courier_id:  165012073 slot_id:  38056729 successful booking:  True
# courier_id:  165012073 slot_id:  38056732 successful booking:  True
# courier_id:  165012073 slot_id:  38056777 successful booking:  True
# courier_id:  165012073 slot_id:  38056780 successful booking:  True
# courier_id:  165012073 slot_id:  38056783 successful booking:  True
# courier_id:  165012073 slot_id:  38056786 successful booking:  True
# courier_id:  165012073 slot_id:  38056789 successful booking:  True
# courier_id:  165012073 slot_id:  38056792 successful booking:  True
# courier_id:  165012073 slot_id:  38056795 successful booking:  True
# courier_id:  165012073 slot_id:  38056798 successful booking:  True

# %% [markdown]
# # Forecast Tool
#
# * The purpose of this tool is to predict how many active couriers we will have during a specific slot.

# %%
from activeCouriersForecast import Forecaster

city = "TIS"
do_you_want_to_train_the_model = False # change this value to True if you want to train the model

forecaster = Forecaster(city)

if do_you_want_to_train_the_model :
    forecaster.train_model()
    
# Predict
result = forecaster.predict_next_two_days()

# Display results
display(result)
# Out:
# Do you want to add an event ? y/n: n
#     date_data hour_data weekday  expected_couriers  active_couriers
# 0  2024-03-02     23:00     Sat              248.0            211.0
# 1  2024-03-02     22:00     Sat              367.0            286.0
# 2  2024-03-02     21:00     Sat              439.0            354.0
# 3  2024-03-02     20:00     Sat              450.0            396.0
# 4  2024-03-02     19:00     Sat              474.0            373.0
# 5  2024-03-02     18:00     Sat              373.0            333.0
# 6  2024-03-02     17:00     Sat              292.0            258.0
# 7  2024-03-02     16:00     Sat              260.0            243.0
# 8  2024-03-02     15:00     Sat              271.0            243.0
# 9  2024-03-02     14:00     Sat              315.0            298.0
# 10 2024-03-02     13:00     Sat              322.0            298.0
# 11 2024-03-02     12:00     Sat              236.0            120.0
# 12 2024-03-02     11:00     Sat              116.0             67.0
# 13 2024-03-02     10:00     Sat               41.0             38.0
# 14 2024-03-02     09:00     Sat               25.0             21.0
# 15 2024-03-02     01:00     Sat               58.0             26.0
# 16 2024-03-02     00:00     Sat              127.0             77.0
# 17 2024-03-03     23:00     Sun              198.0            111.0
# 18 2024-03-03     22:00     Sun              301.0            249.0
# 19 2024-03-03     21:00     Sun              431.0            354.0
# 20 2024-03-03     20:00     Sun              442.0            396.0
# 21 2024-03-03     19:00     Sun              465.0            396.0
# 22 2024-03-03     18:00     Sun              335.0            254.0
# 23 2024-03-03     17:00     Sun              285.0            258.0
# 24 2024-03-03     16:00     Sun              256.0            243.0
# 25 2024-03-03     15:00     Sun              292.0            237.0
# 26 2024-03-03     14:00     Sun              289.0            237.0
# 27 2024-03-03     13:00     Sun              289.0            237.0
# 28 2024-03-03     12:00     Sun              209.0             18.0
# 29 2024-03-03     11:00     Sun              115.0             44.0
# 30 2024-03-03     10:00     Sun               41.0             38.0
# 31 2024-03-03     09:00     Sun               18.0              7.0
# 32 2024-03-03     01:00     Sun               74.0             36.0
# 33 2024-03-03     00:00     Sun              147.0             81.0
