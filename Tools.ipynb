# %%
# This cell is to ignore ugly warnings 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Automatic Email
#
# **Tool:**
#
# Automatic Email Sender is a tool that sends a report to 3PLs about their fleet performance. The report is sent through email and is divided in 2 parts: 1 in the body of the email and the second in a PDF file. It has different section sections and contains the previous day data or the previous 7 days if the period chosen is "weekly":
# * **AFM actions :** list of couriers affected by AFM and what the 3pl should do about them
# * **Worst Offenders :** list of WO in NS, Reass and CNM and what to do in each case
# * **Fraudulent Couriers :** list of couriers that might have : GPS fraud, CAPUs fraud and other types of fraud
# * **3PL fleet performance VS average performance :** charts of KPIs of 3PL fleet
# * **Active couriers (weekly) :** chart of active couriers VS available couriers
#
# **Guide:**
#
# To use this tool, just execute the cell. If today is monday , the weekly report is sent. Otherwise, the daily report is sent.
# You can force a certain period by adding an argument (either "weekly" or "daily") to the function: send_reports("\[period\]").
# The last step is the only manual step and it is allowing the tool the access to your Gmail account to send the emails.
#
# **Important!**
#
# Before confirming sending the emails, always check if the pdf reports are correct by checking the date and whether some sections are missing. Check all reports to confirm!

# %%
from AutomaticEmailSender import send_reports

send_reports()

# %% [markdown]
# # Admin Manager (WIP)
#
# **Tool:**
#
# Admin manager is a tool that allows you to interact with Admin Panel through code. This allows mass action that otherwise would take a lot of time.
#
# **Guide:**
#
# To use this tool, you need an access token. To get your token, follow the steps in the video below and grab the "accessToken" instead of "refreshToken". Watch the video you will notice it.
# https://drive.google.com/file/d/12_3gsVB96Oobn6MW4xiUBY4DPHBZydjL/view
#
# **Functionalities:**
#    * rebook_kickedout_couriers(file,courier_id:optional,slot_id:optional)
#    * setup_new_couriers_profiles()
#
# **Important!**
#
# Do not forget to download data from this sheet **after** running it. After downloading it do not change the name, it needs to be "TN Booked Slots _ Couriers (deprecated) - Kickouts" (until we find a better name). Finally do not forget to change the token using the guide above, old tokens might not work.
#
#
# ![image.png](attachment:image.png)

# %%
from Admin import Admin

token = "eyJraWQiOiJvbGQiLCJhbGciOiJSUzUxMiJ9..kXlqz-IVuQ9MEryL7eeK_xAe1FnUKhPSc1VNfWVk0e9o24Hw6sJD0lvpOBruNLxPQpGblwy156jcslSxJMgO9s8NQB969Lz_bbO4d3Bmj-HE9BagSMuGiq2krJFDAOD8lo9C5RjghrAuwAgVgAYX0KKgPoYqB4TKFbD_9zeFd53FO1M6J-8kKiDtxU6ymAhY8Gys2ghquQijYfOMnAJv7eBl2NAQO4zFv9ShbTzGH9vUx7Tz2QZpAaZrz3DmwYCiuCn-AjuqiWeJ_biksspOubTMVTr8xRSG44j7Wb8fEOYfjK120qW1X1zvmKwrf-Qg6sGZDD6NjdtW-ogQqZJUAQ"
refresh_token = "eyJraWQiOiJvbGQiLCJhbGciOiJSUzUxMiJ9.eyJpYXQiOjE3MDkzMTU2NzEsImlzcyI6ImF1dGgiLCJyb2xlIjoiUkVGUkVTSCIsInBheWxvYWQiOiJ7XCJ1c2VySWRcIjoxNTYyNzI4NDMsXCJncmFudFR5cGVcIjpcIlNTT1wifSIsInZlcnNpb24iOiJWMiIsImp0aSI6ImU4NjJhNTVlLTUwYTctNDkxNS05NjcxLWJhOWVmZGE4NzkwZCJ9.CmHlV3x8q328cWJRfoB35mGk-P0y4ad4G_U-RQCw3rQh0vzFMHakSlxMnmYdDe80qWz8w_WGi2joeKDtwTw9xAPyg2eDLmxGNY1W1tDfPSXxZjouqhbu0lQ1fdr1vBLP9fcTFFhLGeqVDFxRbPcQ38FZmrtUa11XQUjMVemfGpojX3U5iMt-JxN2zrYYDrOoZDHyWwNKjMwVQHuDUVqeMHLE_Smi-1QyYnASYdOymInCgAS_f172xTNmblQbZ8B8sVceXRQYxmh0Kdqy_oDUJh-jxcHjwTKl8shp5zLnWqxEuTTo4rSoFnXC10joPUyk8ybZMvZW2ha0ioBv503_tQ"
admin = Admin(token,refresh_token)

# %%
admin.courier_disable(165012073,"FRAUD")
# Out:
# {'error': {'userInfo': {},
#   'domain': 'com.glovoapp.core-services',
#   'requestId': '6072301447179286534'}}

# %%
# rebook kicked out (late check in and reassignement) couriers during saturation
file = "data/TN kicked out couriers in current slot - Kickouts.csv"
admin.rebook_kickedout_couriers(file)

# %%
# setup newly onboarded couriers profiles
file = "data/Fleet Overview - TIS - Formation.csv"
admin.setup_new_couriers_profiles(file)
# Out:
# REAREAZ
# no
# REAREAZ
# no
# REAREAZ
# no
# REAREAZ
# no
# REAREAZ
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# REAREAZ
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# REAREAZ
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# nan
# no
# ...

# %% [markdown]
# # Forecast Tool
#
# * The purpose of this tool is to predict how many active couriers we will have during a specific slot.

# %%
from ActiveCouriersForecast import Forecaster

city = "SOU"
do_you_want_to_train_the_model = False # change this value to True if you want to train the model

forecaster = Forecaster(city)

if do_you_want_to_train_the_model :
    forecaster.train_model()
    
# Predict
result = forecaster.predict_next_two_days()

# Display results
display(result)
# Out:
# Do you want to add an event ? y/n: n
#     date_data hour_data weekday  expected_couriers  active_couriers
# 0  2024-03-05     23:00     Tue               12.0              8.0
# 1  2024-03-05     22:00     Tue               18.0             14.0
# 2  2024-03-05     21:00     Tue               22.0             13.0
# 3  2024-03-05     20:00     Tue               25.0             18.0
# 4  2024-03-05     19:00     Tue               22.0             17.0
# 5  2024-03-05     18:00     Tue               20.0             18.0
# 6  2024-03-05     17:00     Tue               15.0             11.0
# 7  2024-03-05     16:00     Tue               15.0             11.0
# 8  2024-03-05     15:00     Tue               15.0             11.0
# 9  2024-03-05     14:00     Tue               14.0             11.0
# 10 2024-03-05     13:00     Tue               18.0             12.0
# 11 2024-03-05     12:00     Tue               20.0             12.0
# ...

# %%
# import necessary libraries
import re
import pandas as pd
import io
import requests
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
import pandas as pd
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from random import randint
from time import sleep
import matplotlib.pyplot as plt
import seaborn as sns

# %%
chrome_options = Options()
headless = False
chrome_options.add_argument("--start-maximized")
user_data_directory = 'C:/Program Files/Google/Chrome/Application/chrome.exe --profile_directory="profile 16"'
chrome_options.add_argument(f'user-data-dir={user_data_directory}')
options.add_argument("disable-infobars")
options.add_argument("--disable-extensions")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--no-sandbox")
if headless:
    options.add_argument('--headless')
options.binary_location = "/usr/bin/chromium-browser"

options = webdriver.ChromeOptions()
driver = webdriver.Chrome(options=chrome_options)
driver.switch_to.default_content()
url= "google.com"
driver.get(url)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[28], line 15
#      12 options.binary_location = "/usr/bin/chromium-browser"
#      14 options = webdriver.ChromeOptions()
# ---> 15 driver = webdriver.Chrome(options=chrome_options)
#      16 driver.switch_to.default_content()
#      17 url= "google.com"
#
# File ~\anaconda3\Lib\site-packages\selenium\webdriver\chrome\webdriver.py:45, in WebDriver.__init__(self, options, service, keep_alive)
#      42 service = service if service else Service()
#      43 options = options if options else Options()
# ---> 45 super().__init__(
#      46     browser_name=DesiredCapabilities.CHROME["browserName"],
#      47     vendor_prefix="goog",
#      48     options=options,
#      49     service=service,
#      50     keep_alive=keep_alive,
#      51 )
#
# ...
