# %%
# This cell is to ignore ugly warnings 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Automatic Email
#
# **Tool:**
#
# Automatic Email Sender is a tool that sends a report to 3PLs about their fleet performance. The report is sent through email and is divided in 2 parts: 1 in the body of the email and the second in a PDF file. It has different section sections and contains the previous day data or the previous 7 days if the period chosen is "weekly":
# * **AFM actions :** list of couriers affected by AFM and what the 3pl should do about them
# * **Worst Offenders :** list of WO in NS, Reass and CNM and what to do in each case
# * **Fraudulent Couriers :** list of couriers that might have : GPS fraud, CAPUs fraud and other types of fraud
# * **3PL fleet performance VS average performance :** charts of KPIs of 3PL fleet
# * **Active couriers (weekly) :** chart of active couriers VS available couriers
#
# **Guide:**
#
# To use this tool, just execute the cell. If today is monday , the weekly report is sent. Otherwise, the daily report is sent.
# You can force a certain period by adding an argument (either "weekly" or "daily") to the function: send_reports("\[period\]").
# The last step is the only manual step and it is allowing the tool the access to your Gmail account to send the emails.
#
# **Important!**
#
# Before confirming sending the emails, always check if the pdf reports are correct by checking the date and whether some sections are missing. Check all reports to confirm!

# %%
from AutomaticEmailSender import send_reports

send_reports()
# Out:
# step 1 (done): courier data loaded
# step 2 (done): courier data saved
# step 3 (done): courier data processed
# step 4 (done): reports generated
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=315024983370-mbe70gcargecd0eh2q68sshv909965rm.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A57544%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fgmail.send&state=kUL8zMnhZam7UKdpsEqcYnMXsfyR0b&access_type=offline
# ---------------------------------------------------------------------------
# SMTPRecipientsRefused                     Traceback (most recent call last)
# Cell In[2], line 3
#       1 from AutomaticEmailSender import send_reports
# ----> 3 send_reports()
#
# File ~\Desktop\ops\AutomaticEmailSender.py:168, in send_reports(current_period)
#     166 print("step 4 (done): reports generated")
#     167 # Send all emails
# --> 168 send_all_emails(all_3pls, emails_3pls, messages)
#     169 print("step 5 (done): reports sent")
#
# File ~\Desktop\ops\emailManager\emailSender.py:40, in send_all_emails(all_3pls, emails_3pls, messages)
#      38 message.attach(attach)
#      39 # server.sendmail(sender_email, "montassar.chihi@glovoapp.com", message.as_string())
# ---> 40 server.sendmail(sender_email, recipient_email + 'montassar.chihi@glovoapp.com', message.as_string())
#
# File ~\anaconda3\Lib\smtplib.py:901, in SMTP.sendmail(self, from_addr, to_addrs, msg, mail_options, rcpt_options)
#     898 if len(senderrs) == len(to_addrs):
#     899     # the server refused all our recipients
#     900     self._rset()
# --> 901     raise SMTPRecipientsRefused(senderrs)
#     902 (code, resp) = self.data(msg)
#     903 if code != 250:
#
# SMTPRecipientsRefused: {'mc.montassar.chihi@gmail.commontassar.chihi@glovoapp.com': (553, b'5.1.3 The recipient address <mc.montassar.chihi@gmail.commontassar.chihi@glo\n5.1.3 voapp.com> is not a valid RFC 5321 address. For more information, go\n5.1.3 to\n5.1.3  https://support.google.com/a/answer/3221692 and review RFC 5321\n5.1.3 specifications. h9-20020a05600c314900b00414691e7c4bsm592515wmo.29 - gsmtp')}

# %%
from google_auth_oauthlib.flow import InstalledAppFlow
from googleapiclient.discovery import build
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.application import MIMEApplication

with smtplib.SMTP_SSL('smtp.gmail.com', 465) as server:
    sender_email = "montassar.chihi@glovoapp.com"
    sender_password = "gajf yyhg eqey jwzv"  # for personal account (mc...) "crow bslo masr oulu"
    server.login(sender_email, sender_password)
    SCOPES = [
        "https://www.googleapis.com/auth/gmail.send"
    ]
    flow = InstalledAppFlow.from_client_secrets_file('utilities/credentials.json', SCOPES)
    creds = flow.run_local_server(port=0)
    service = build('gmail', 'v1', credentials=creds)

    # recipient_email = emails_3pls[current_3pl]
    recipient_email = "mc.montassar.chihi@gmail.com"

    message = MIMEMultipart()
    message['Subject'] = "subject"
    message['From'] = sender_email
    message['To'] = recipient_email
    html_part = MIMEText("<br>hi", "html")
    message.attach(html_part)
        # server.sendmail(sender_email, "montassar.chihi@glovoapp.com", message.as_string())
    server.sendmail(sender_email, recipient_email + ', tbs.montassar.chihi@gmail.com', message.as_string())
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=315024983370-mbe70gcargecd0eh2q68sshv909965rm.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A57674%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fgmail.send&state=j6wvWpKr2uPyo2rh1Usge0qTZbFQJx&access_type=offline

# %% [markdown]
# # Forecast Tool
#
# * The purpose of this tool is to predict how many active couriers we will have during a specific slot.

# %%
from ActiveCouriersForecast import Forecaster

city = "TIS"
do_you_want_to_train_the_model = False # change this value to True if you want to train the model

forecaster = Forecaster(city)

if do_you_want_to_train_the_model :
    forecaster.train_model()
    
# Predict
result = forecaster.predict_next_two_days()

# Display results
display(result)
