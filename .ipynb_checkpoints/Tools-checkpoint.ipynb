# %%
# This cell is to ignore ugly warnings 
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Automatic Email
#
# **Tool:**
#
# Automatic Email Sender is a tool that sends a report to 3PLs about their fleet performance. The report is sent through email and is divided in 2 parts: 1 in the body of the email and the second in a PDF file. It has different section sections and contains the previous day data or the previous 7 days if the period chosen is "weekly":
# * **AFM actions :** list of couriers affected by AFM and what the 3pl should do about them
# * **Worst Offenders :** list of WO in NS, Reass and CNM and what to do in each case
# * **Fraudulent Couriers :** list of couriers that might have : GPS fraud, CAPUs fraud and other types of fraud
# * **3PL fleet performance VS average performance :** charts of KPIs of 3PL fleet
# * **Active couriers (weekly) :** chart of active couriers VS available couriers
#
# **Guide:**
#
# To use this tool, just execute the cell. If today is monday , the weekly report is sent. Otherwise, the daily report is sent.
# You can force a certain period by adding an argument (either "weekly" or "daily") to the function: send_reports("\[period\]").
# The last step is the only manual step and it is allowing the tool the access to your Gmail account to send the emails.
#
# **Important!**
#
# Before confirming sending the emails, always check if the pdf reports are correct by checking the date and whether some sections are missing. Check all reports to confirm!

# %%
from AutomaticEmailSender import send_reports

send_reports()
# Out:
# courier df data loaded
# Open the following URL in browser for the external authentication:
# https://starburst.g8s-data-platform-prod.glovoint.com/oauth2/token/initiate/c1f10d121e5e1e9df11921eda0caeb650433ec085df71ed70972088c9843d775
# step 1 (done): courier data loaded
# step 2 (done): courier data saved
# step 3 (done): courier data processed
# error :7
# cannot convert float NaN to integer
# step 4 (done): reports generated
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=315024983370-mbe70gcargecd0eh2q68sshv909965rm.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A55487%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fgmail.send&state=EmawGgT2tBSbaihMagLuzNQaEykqNz&access_type=offline
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 3
#       1 from AutomaticEmailSender import send_reports
# ----> 3 send_reports()
#
# File ~\Desktop\ops\AutomaticEmailSender.py:170, in send_reports(current_period)
#     168 print("step 4 (done): reports generated")
#     169 # Send all emails
# --> 170 send_all_emails(all_3pls, emails_3pls, messages)
#     171 print("step 5 (done): reports sent")
#
# File ~\Desktop\ops\emailManager\emailSender.py:27, in send_all_emails(all_3pls, emails_3pls, messages)
#      24 recipient_email = emails_3pls[current_3pl]
#      25 #         recipient_email = "mc.montassar.chihi@gmail.com"
# ---> 27 filename = messages[current_3pl]["file"]
#      28 message = MIMEMultipart()
#      29 message['Subject'] = messages[current_3pl]["subject"]
#
# KeyError: '7'

# %% [markdown]
# # Admin Manager (WIP)
#
# **Tool:**
#
# Admin manager is a tool that allows you to interact with Admin Panel through code. This allows mass action that otherwise would take a lot of time.
#
# **Guide:**
#
# To use this tool, you need an access token. To get your token, follow the steps in the video below and grab the "accessToken" instead of "refreshToken". Watch the video you will notice it.
# https://drive.google.com/file/d/12_3gsVB96Oobn6MW4xiUBY4DPHBZydjL/view
#
# **Functionalities:**
#    * rebook_kickedout_couriers(token,courier_id:optional,slot_id:optional) :
#        * to rebook all couriers mentioned in Kickouts sheet, *do not add* a courier_id and a slot_id
#        * to rebook a specific courier, add the optional arguments
#
# **Important!**
#
# Do not forget to download data from this sheet **after** running it. After downloading it do not change the name, it needs to be "TN Booked Slots _ Couriers (deprecated) - Kickouts" (until we find a better name). Finally do not forget to change the token using the guide above, old tokens might not work.
#
#
# ![image.png](attachment:image.png)

# %%
from adminManager import rebook_kickedout_couriers

# update the token 
token = "eyJraWQiOiJvbGQiLCJhbGciOiJSUzUxMiJ9..WLETI0glGz7roPbSoZEm9PF4TvckPKBQHw61AWDh0EugsjQC_y6kfgqc8dN5aomOJ80fYCHqBqyJwvHhsqCf92Ky-r3FkWC3bQlmu-pCFwhMblEzNbIJm9uq5wtnFccO28rDu3UREUXBeAPTCK0SDHSWo6A1nlpiYA0wdGorrFxi6HAWWZIjAgdu5yz5e9o-IkIJqy7RkxkmUsj8EZu4Y9PRcqVIEAxaUy-bVH8q29czrXwf6R6Z9LoRNJkq0qwr1au5nyEQM31ZrNRJomDDRbep9ZjBl4ubj9bRtG9Tb5kRmkgWjlXXpVmeHViFmDeG9Uj9ve2LrhE54qXhM41eQA"

# do not forget to download the data from kickouts sheet everytime (link above) and put it in data folder

# rebook kicked out (late check in and reassignement) couriers during saturation
rebook_kickedout_couriers(token)
# Out:
# 124485524 37711910 (True, {})
# 124485524 37711910 (True, {})
# 126416288 37711908 (True, {})
# 126416288 37711908 (True, {})
# 134372652 37711910 (True, {})
# 134372652 37711910 (True, {})
# 134374111 37711909 (True, {})
# 134374111 37711909 (True, {})
# 137055014 37705932 (True, {})
# 137055014 37705932 (True, {})
# 140085923 37711910 (True, {})
# 140085923 37711910 (True, {})
# 142815911 37711910 (True, {})
# 142815911 37711910 (True, {})
# 145432319 37711910 (True, {})
# 145432319 37711910 (True, {})
# 146120081 37711910 (True, {})
# 146120081 37711910 (True, {})
# 150064243 37711910 (True, {})
# 150064243 37711910 (True, {})
# 150828079 37711910 (True, {})
# 150828079 37711910 (True, {})
# 150833700 37711909 (True, {})
# 150833700 37711909 (True, {})
# 150833713 37711909 (True, {})
# 150833713 37711909 (True, {})
# 150833826 37711909 (True, {})
# 150833826 37711909 (True, {})
# 151255929 37711910 (True, {})
# 151255929 37711910 (True, {})
# 151325953 37711909 (True, {})
# 151325953 37711909 (True, {})
# 151382619 37711909 (True, {})
# 151382619 37711909 (True, {})
# 151716649 37711909 (True, {})
# 151716649 37711909 (True, {})
# 153989186 37705932 (True, {})
# 153989186 37705932 (True, {})
# 155885717 37711909 (True, {})
# 155885717 37711909 (True, {})
# 157351523 37711910 (True, {})
# 157351523 37711910 (True, {})
# 157892256 37711908 (True, {})
# 157892256 37711908 (True, {})
# 159523840 37711910 (True, {})
# 159523840 37711910 (True, {})
# 159527390 37711908 (True, {})
# 159527390 37711908 (True, {})
# 159529533 37711910 (True, {})
# 159529533 37711910 (True, {})
# 159627313 37711909 (True, {})
# 159627313 37711909 (True, {})
# 159628695 37711910 (True, {})
# 159628695 37711910 (True, {})
# 160293001 37711910 (True, {})
# 160293001 37711910 (True, {})
# 160587667 37711908 (True, {})
# 160587667 37711908 (True, {})
# 161232889 37711910 (True, {})
# 161232889 37711910 (True, {})
# 161242870 37711910 (True, {})
# 161242870 37711910 (True, {})
# 161759620 37711909 (True, {})
# 161759620 37711909 (True, {})
# 163030546 37711910 (True, {})
# 163030546 37711910 (True, {})
# 163037300 37711910 (True, {})
# 163037300 37711910 (True, {})
# 163413685 37711910 (True, {})
# 163413685 37711910 (True, {})
# 164607518 37709784 (True, {})
# 164607518 37709784 (True, {})
# 164742323 37711910 (True, {})
# 164742323 37711910 (True, {})
# 164817682 37711910 (True, {})
# 164817682 37711910 (True, {})
